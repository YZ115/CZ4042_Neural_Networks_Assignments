# %%
#
# Project 1, source code for part A
#

import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
import math
from sklearn.model_selection import train_test_split
import time

# %%
# scale data (set range min and max of 0 and 1 respectively)
def scale(X, X_min, X_max):
    return (X - X_min)/(X_max-X_min)

# Default values
NUM_CLASSES = 3
NUM_FEATURES = 21

epochs = 1000
batch_size = 64
num_neurons = 10
seed = 10
decay_beta = 0.000001
learning_rate = 0.01
hidden_layer = 5

np.random.seed(seed)
tf.random.set_seed(seed)

# %%
#read train data
def get_data():
    train_input = np.genfromtxt('ctg_data_cleaned.csv', delimiter= ',')
    trainX, train_Y = train_input[1:, :21], train_input[1:,-1].astype(int)
    trainX = scale(trainX, np.min(trainX, axis=0), np.max(trainX, axis=0))

    #one hot encoding
    trainY = np.zeros((train_Y.shape[0], NUM_CLASSES))
    trainY[np.arange(train_Y.shape[0]), train_Y-1] = 1 
    
    return trainX, trainY

#Split train and test data (70:30)
def split_data(trainX, trainY):
    train_X, test_X, train_Y, test_Y = train_test_split(trainX, trainY, test_size=0.3)
    print("TrainX: ",train_X.shape)
    print("TestX: ",test_X.shape)
    print("TrainY: ",train_Y.shape)
    print("TestY: ",test_Y.shape)
    return train_X, test_X, train_Y, test_Y

# %%
#model
def get_model(decay_beta):
    model = keras.Sequential([
        keras.layers.Dense(hidden_layer, use_bias = True, input_shape = (NUM_FEATURES,), activation='relu', kernel_regularizer = tf.keras.regularizers.l2(decay_beta)),
        keras.layers.Dense(NUM_CLASSES, use_bias=True, activation='softmax')
    ])

    SGD_opt = keras.optimizers.SGD(learning_rate=learning_rate)

    model.compile(optimizer=SGD_opt,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
def fit_model(train_X, train_Y, test_X, test_Y, epochs, batch_size, model):
    timeTaken=timeCallback()
    history = model.fit(train_X, train_Y,
                        epochs=epochs,
                        callbacks = [timeTaken],
                        verbose = 2,
                        batch_size=batch_size,
                        validation_data = (test_X, test_Y),
                        shuffle=True)
    timeTaken = np.mean(timeTaken.logs)
    plt.title('Model Accuracy')
    plt.xlabel('No. epoch')
    plt.ylabel('Accuracy')
    plt.legend(['train data', 'test data'], loc='lower right')
    plt.plot(range(epochs),history.history['accuracy'])
    plt.plot(range(epochs),history.history['val_accuracy'])
    return history, timeTaken
#trainX, trainY = get_data()
#train_X, test_X, train_Y, test_Y = split_data(trainX, trainY)
#model=get_model()
#history, timetaken = fit_model(train_X, train_Y, test_X, test_Y, epochs, batch_size, model)

# %%
def plot_accuracy(acc, test_acc, epochs, beta_decay):
    plt.clf()
    plt.plot(range(epochs), accuracy)
    plt.plot(range(epochs), test_accuracy)
    plt.xlabel('No. epochs')
    plt.ylabel('Accuracy')
    plt.legend(['train data', 'test data'], loc='lower right')
    plt.title('Decay parameter: '+beta_decay)
    
#plot_accuracy(accuracy,val_acc,100,64)

# %%
class timeCallback(tf.keras.callbacks.Callback):
    
    def on_train_begin(self, logs={}):
        self.logs=[]

    def on_epoch_begin(self, epoch, logs={}):
        self.epoch_start = time.time()

    def on_epoch_end(self, epoch, logs={}):
        self.logs.append(time.time() - self.epoch_start)

# %%
def k_fold_CV(k, dataX, dataY, epochs, batch_size, decay_beta):
    interval_length = len(dataX) // k
    k_accuracy = []
    k_accuracy_test = []
    k_loss = []
    k_loss_test = []
    time_log = []
    for i in range(k):
        print("fold number: ",i)
        start_time = time.time()
        
        # get train and test data
        train_X = np.concatenate([dataX[:i * interval_length],dataX[(i + 1) * interval_length:]],axis=0)
        train_Y = np.concatenate([dataY[:i * interval_length],dataY[(i + 1) * interval_length:]],axis=0)
        
        test_X = dataX[i * interval_length: (i + 1) * interval_length]
        test_Y = dataY[i * interval_length: (i + 1) * interval_length]
        
        model = get_model(decay_beta)
        
        history, timeTaken = fit_model(train_X, train_Y, test_X, test_Y, epochs, batch_size, model)
        
        time_log.append(timeTaken)
        k_accuracy.append(history.history['accuracy'])
        k_accuracy_test.append(history.history['val_accuracy'])
        k_loss.append(history.history['loss'])
        k_loss_test.append(history.history['val_loss'])
    
    avg_time=np.mean(time_log)
    return k_accuracy, k_accuracy_test, k_loss, k_loss_test, avg_time

#accuracy, val_acc, loss, val_loss, avg_time = k_fold_CV(3, TrainX, TrainY, 100, 32)
#plot_accuracy(accuracy, val_acc,100)

# %%
def plot_time(decay_param, avg_time):
    plt.clf()
    plt.plot(decay_param, avg_time)
    plt.ylabel('Average time/epoch')
    plt.xlabel('Decay Parameter')
    plt.xticks(decay_param)
    plt.title('Average time/epoch for different decay parameters')

# %%
# Main code
beta_decay = [0, 10**-3, 10**-6, 10**-9, 10**-12]
avg_time_logs = []
acc_log = []
test_acc_log = []
loss_log = []
val_loss_log = []

epochs = 300
batch_size = 32
hidden_layer = 20

TrainX, TrainY = get_data()

for x in beta_decay:
    print("Running model for decay parameter: ",x)
    accuracy, val_acc, loss, val_loss, avg_time = k_fold_CV(5, TrainX, TrainY, epochs, batch_size, x)
    
    acc_log.append([np.mean([y[i] for y in accuracy]) for i in range(epochs)])
    test_acc_log.append([np.mean([y[i] for y in val_acc]) for i in range(epochs)])
    loss_log.append([np.mean([y[i] for y in loss]) for i in range(epochs)])
    val_loss_log.append([np.mean([y[i] for y in val_loss]) for i in range(epochs)])
    
    avg_time_logs.append(avg_time)
# Out:
# Running model for decay parameter:  0
# fold number:  0
# Epoch 1/300
# 54/54 - 0s - loss: 0.8227 - accuracy: 0.7931 - val_loss: 0.9468 - val_accuracy: 0.5765
# Epoch 2/300
# 54/54 - 0s - loss: 0.6090 - accuracy: 0.8289 - val_loss: 1.0127 - val_accuracy: 0.5765
# Epoch 3/300
# 54/54 - 0s - loss: 0.5635 - accuracy: 0.8289 - val_loss: 1.0535 - val_accuracy: 0.5765
# Epoch 4/300
# 54/54 - 0s - loss: 0.5501 - accuracy: 0.8289 - val_loss: 1.0482 - val_accuracy: 0.5765
# Epoch 5/300
# 54/54 - 0s - loss: 0.5422 - accuracy: 0.8289 - val_loss: 1.0543 - val_accuracy: 0.5765
# Epoch 6/300
# 54/54 - 0s - loss: 0.5352 - accuracy: 0.8289 - val_loss: 1.0490 - val_accuracy: 0.5765
# Epoch 7/300
# 54/54 - 0s - loss: 0.5287 - accuracy: 0.8289 - val_loss: 1.0263 - val_accuracy: 0.5765
# Epoch 8/300
# 54/54 - 0s - loss: 0.5221 - accuracy: 0.8289 - val_loss: 1.0108 - val_accuracy: 0.5765
# Epoch 9/300
# 54/54 - 0s - loss: 0.5157 - accuracy: 0.8289 - val_loss: 0.9979 - val_accuracy: 0.5765
# Epoch 10/300
# ...

# %%
# Accuracy vs Number of epochs for different decay parameters
print(len(acc_log[0]))
plt.figure(figsize = (10,6))
for i in range(len(acc_log)):
    plt.plot(acc_log[i])
plt.legend(['decay param = 0','decay param = 10^-3','decay param = 10^-6','decay param = 10^9','decay param = 10^12'])
plt.xlabel('No. epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy vs Number of epochs for different decay parameters')
plt.savefig('Question1D_concat_acc.png')
# Out:
# 300

# %%
#Zoomed in
print(len(acc_log[0]))
for i in range(len(acc_log)):
    plt.plot(acc_log[i])
plt.legend(['decay param = 0','decay param = 10^-3','decay param = 10^-6','decay param = 10^9','decay param = 10^12'],
          fontsize = 7.5)
plt.xlabel('No. epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy vs Number of epochs for different decay parameters')
plt.savefig('Question1D_concat_acc_zoom.png')
plt.xlim(270,300)
plt.ylim(0.9,0.906)
# Out:
# 300
# (0.9, 0.906)

# %%
# Test accuracy vs Number of epochs for different decay parameters
print(len(test_acc_log[0]))
plt.figure(figsize = (9,5))
for i in range(len(test_acc_log)):
    plt.plot(test_acc_log[i])
plt.legend(['decay param = 0','decay param = 10^-3','decay param = 10^-6','decay param = 10^9','decay param = 10^12'])
plt.xlabel('No. epochs')
plt.ylabel('Accuracy')
plt.title('Test accuracy vs Number of epochs for different decay parameters')
plt.savefig('Question1D_concat_testacc.png')
# Out:
# 300

# %%
# Zoomed in
print(len(test_acc_log[0]))
for i in range(len(test_acc_log)):
    plt.plot(test_acc_log[i])
plt.legend(['decay param = 0','decay param = 10^-3','decay param = 10^-6','decay param = 10^9','decay param = 10^12'],
          fontsize = 8, loc='lower right')
plt.xlabel('No. epochs')
plt.ylabel('Accuracy')
plt.title('Test accuracy vs Number of epochs for different decay parameters')
plt.savefig('Question1D_concat_testacc_zoom.png')
plt.xlim(250,300)
plt.ylim(0.84,0.873)
# Out:
# 300
# (0.84, 0.873)

# %%
# Optimal decay parameter = 10^-9
plt.figure(figsize = (9,5))
plt.plot(acc_log[3])
plt.plot(test_acc_log[3])
plt.legend(['Train data','Test data'], loc='lower right')
plt.xlabel('No. epochs')
plt.ylabel('Accuracy')
plt.title('Test accuracy vs epochs for optimal decay parameter 10^-9')
plt.savefig('Question1D_optimal.png')
