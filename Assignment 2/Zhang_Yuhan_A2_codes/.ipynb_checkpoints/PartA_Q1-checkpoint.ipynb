# %%
#
# Project 2, starter code Part a
#

import os
import pickle

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import layers
from tensorflow.python.client import device_lib
from tensorflow.keras import models
from skimage import color

# %%
# This is required when using GPU
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
            print(gpus)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
        devices = device_lib.list_local_devices()
        avail_gpu = [x for x in devices if x.device_type == 'GPU']
        print('\n',avail_gpu)
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
else:
    print("No gpus available")

# %%
# Fixed, no need change
def load_data(file):
    file = 'data\\'+file
    with open(file, 'rb') as fo:
        try:
            samples = pickle.load(fo)
        except UnicodeDecodeError:  # python 3.x
            fo.seek(0)
            samples = pickle.load(fo, encoding='latin1')

    data, labels = samples['data'], samples['labels']

    data = np.array(data, dtype=np.float32) / 255
    data = tf.reshape(data, [-1,3, 32, 32])
    data = tf.transpose(data,(0,2,3,1))
    labels = np.array(labels, dtype=np.int32)
    return data, labels

# %%
def make_model(num_ch_c1, num_ch_c2, use_dropout):

    model = tf.keras.Sequential()
    model.add(layers.Input(shape=(32,32,3)))
    model.add(layers.Conv2D(num_ch_c1, 9, padding='valid', activation='relu', input_shape=(None, None, 3)))
    model.add(layers.MaxPool2D(pool_size=(2, 2), strides=2, padding='valid'))
    model.add(layers.Conv2D(num_ch_c2, 5, padding='valid', activation='relu'))
    model.add(layers.MaxPool2D(pool_size=(2, 2), strides=2, padding='valid'))
    model.add(layers.Flatten())
    model.add(layers.Dense(300, activation=None))
    model.add(layers.Dense(10, use_bias=True, activation='softmax', input_shape=(300,)))  # Here no softmax because we have combined it with the loss
    return model
#model = make_model(50,60,False)
#model.summary()

# %%
def save_model(num_ch_c1,num_ch_c2,optimizer_,use_dropout):
    # Create folder to store models and results
    if not os.path.exists('./models'):
        os.mkdir('./models')
    if not os.path.exists('./results'):
        os.mkdir('./results')

    # Save model
    if use_dropout:
        model.save(f'./models/{num_ch_c1}_{num_ch_c2}_{optimizer_}_dropout')
    else:
        model.save(f'./models/{num_ch_c1}_{num_ch_c2}_{optimizer_}_no_dropout')

# %%
def create_opt(optimizer_,lr):
    if optimizer_ == 'SGD':
        optimizer = keras.optimizers.SGD(learning_rate=lr)
    elif optimizer_ == 'SGD-momentum':  # Question 3(a)
        optimizer = keras.optimizers.SGD(learning_rate=lr, momentum = 0.1)
    elif optimizer_ == 'RMSProp':  # Question 3(b)
        optimizer = keras.optimizers.RMSprop(learning_rate=lr)
    elif optimizer_ == 'Adam':  # Question 3(c)
        optimizer = keras.optimizers.Adam(learning_rate=lr)
    else:
        raise NotImplementedError(f'You do not need to handle [{optimizer_}] in this project.')
    return optimizer

# %%
# Save the plot for losses
def plot_loss(loss,test_loss,use_dropout):
    train_loss = loss
    val_loss = test_loss
    plt.figure(figsize=(10,6))
    plt.plot(range(1, len(train_loss) + 1), train_loss, label='Train')
    plt.plot(range(1, len(val_loss) + 1), val_loss, label='Test')
    plt.title('Model Loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend()
    if use_dropout:
        plt.savefig(
            f'./results/{num_ch_c1}_{num_ch_c2}_{optimizer_}_dropout_loss.pdf')
    else:
        plt.savefig(
            f'./results/{num_ch_c1}_{num_ch_c2}_{optimizer_}_no_dropout_loss.pdf'
        )
    plt.show()
    plt.close()

# %%
# Save the plot for accuracy
def plot_acc(acc,val_acc,use_dropout):
    train_acc = acc
    test_acc = val_acc
    plt.figure(figsize=(10,8))
    plt.plot(range(1, len(train_acc) + 1), train_acc, label='Train')
    plt.plot(range(1, len(test_acc) + 1), test_acc, label='Test')
    plt.title('Model Accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend()
    if use_dropout:
        plt.savefig(
            f'./results/QuestionA1_{num_ch_c1}_{num_ch_c2}_{optimizer_}_dropout_accuracy.pdf'
        )
    else:
        plt.savefig(
            f'./results/QuestionA1_{num_ch_c1}_{num_ch_c2}_{optimizer_}_no_dropout_accuracy.pdf'
        )
    plt.show()
    plt.close()

# %%
def load_history(path):
    path = 'histories\\'+path
    with open(path, 'rb') as fo:
        try:
            history = pickle.load(fo)
        except UnicodeDecodeError:  # python 3.x
            fo.seek(0)
            history = pickle.load(fo, encoding='latin1')

    #data, labels = history['data'], history['labels']

    #history = np.array(history, dtype=np.float32) / 255
    return history

# %%
seed = 0
np.random.seed(seed)
tf.random.set_seed(seed)

num_ch_c1 = 50
num_ch_c2 = 60

epochs = 1000
batch_size = 128
learning_rate = 0.001
optimizer_ = 'SGD' 
use_dropout = False 

model = make_model(num_ch_c1, num_ch_c2, use_dropout)
loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

optimizer = create_opt(optimizer_,learning_rate)

# Training and test
x_train, y_train = load_data('data_batch_1')
x_test, y_test = load_data('test_batch_trim')

# %%
# Training
model.compile(optimizer=optimizer, loss=loss, metrics='accuracy')
history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(x_test, y_test))

''' Fill in Question 1(b) here. This website may help:
        https://towardsdatascience.com/visualizing-intermediate-activation-in-convolutional-neural-networks-with-keras-260b36d60d0
'''

save_model(num_ch_c1,num_ch_c2,optimizer_,use_dropout)

# Save the plot for losses
plot_loss(history.history['loss'],history.history['val_loss'],use_dropout)

# Save the plot for accuracies
plot_acc(history.history['accuracy'],history.history['val_accuracy'],use_dropout)
# Out:
# Epoch 1/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 2.3175 - accuracy: 0.1027 - val_loss: 2.3032 - val_accuracy: 0.1250
# Epoch 2/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 2.3018 - accuracy: 0.1277 - val_loss: 2.2944 - val_accuracy: 0.1375
# Epoch 3/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 2.2918 - accuracy: 0.1405 - val_loss: 2.2870 - val_accuracy: 0.1515
# Epoch 4/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 2.2848 - accuracy: 0.1547 - val_loss: 2.2797 - val_accuracy: 0.1610
# Epoch 5/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 2.2778 - accuracy: 0.1698 - val_loss: 2.2722 - val_accuracy: 0.1825
# Epoch 6/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 2.2706 - accuracy: 0.1817 - val_loss: 2.2641 - val_accuracy: 0.1930
# Epoch 7/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 2.2627 - accuracy: 0.1961 - val_loss: 2.2554 - val_accuracy: 0.1930
# Epoch 8/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 2.2523 - accuracy: 0.2067 - val_loss: 2.2456 - val_accuracy: 0.2005
# Epoch 9/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 2.2437 - accuracy: 0.2075 - val_loss: 2.2335 - val_accuracy: 0.2170
# Epoch 10/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 2.2285 - accuracy: 0.2211 - val_loss: 2.2195 - val_accuracy: 0.2270
# Epoch 11/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 2.2159 - accuracy: 0.2254 - val_loss: 2.2038 - val_accuracy: 0.2295
# Epoch 12/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 2.1979 - accuracy: 0.2425 - val_loss: 2.1863 - val_accuracy: 0.2270
# Epoch 13/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 2.1842 - accuracy: 0.2297 - val_loss: 2.1666 - val_accuracy: 0.2410
# Epoch 14/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 2
1000
# 79/79 [==============================] - 1s 9ms/step - loss: 1.3035 - accuracy: 0.5449 - val_loss: 1.4030 - val_accuracy: 0.4970
# Epoch 320/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 1.2776 - accuracy: 0.5547 - val_loss: 1.3933 - val_accuracy: 0.4985
# Epoch 321/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 1.2671 - accuracy: 0.5549 - val_loss: 1.4051 - val_accuracy: 0.5010
# Epoch 322/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 1.2869 - accuracy: 0.5483 - val_loss: 1.4207 - val_accuracy: 0.5040
# Epoch 323/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 1.2687 - accuracy: 0.5499 - val_loss: 1.4204 - val_accuracy: 0.4890
# Epoch 324/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 1.2951 - accuracy: 0.5405 - val_loss: 1.4398 - val_accuracy: 0.4835
# Epoch 325/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 1.2775 - accuracy: 0.5485 - val_loss: 1.5246 - val_accuracy: 0.4485
# Epoch 326/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 1.2735 - accuracy: 0.5500 - val_loss: 1.4634 - val_accuracy: 0.4850
# Epoch 327/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 1.2840 - accuracy: 0.5461 - val_loss: 1.5513 - val_accuracy: 0.4410
# Epoch 328/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 1.2863 - accuracy: 0.5442 - val_loss: 1.6320 - val_accuracy: 0.4075
# Epoch 329/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 1.2697 - accuracy: 0.5526 - val_loss: 1.4459 - val_accuracy: 0.4865
# Epoch 330/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 1.2708 - accuracy: 0.5520 - val_loss: 1.3979 - val_accuracy: 0.5145
# Epoch 331/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 1.2668 - accuracy: 0.5498 - val_loss: 1.4822 - val_accuracy: 0.4615
# Epoch 332/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 1.2803 - accuracy: 0.5506 - val_loss: 1.4141 - val_accuracy: 0.4945
# Epoch 333/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 1.2651 - accuracy: 0.5479 - val_loss: 1.5169 - val_accuracy: 0.4570
# Epoch 334/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 1.2688 - accuracy: 0.5580 - val_loss: 1.4121 - val_accuracy: 0.4895
# ...
# Epoch 896/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.8007 - accuracy: 0.7288 - val_loss: 1.6130 - val_accuracy: 0.4665
# Epoch 897/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7884 - accuracy: 0.7341 - val_loss: 1.2988 - val_accuracy: 0.5680
# Epoch 898/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7879 - accuracy: 0.7310 - val_loss: 1.3189 - val_accuracy: 0.5605
# Epoch 899/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.8088 - accuracy: 0.7362 - val_loss: 1.5887 - val_accuracy: 0.4790
# Epoch 900/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.8046 - accuracy: 0.7327 - val_loss: 1.3395 - val_accuracy: 0.5575
# Epoch 901/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7938 - accuracy: 0.7246 - val_loss: 1.3619 - val_accuracy: 0.5570
# Epoch 902/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7930 - accuracy: 0.7260 - val_loss: 1.3723 - val_accuracy: 0.5605
# Epoch 903/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7773 - accuracy: 0.7376 - val_loss: 1.3792 - val_accuracy: 0.5575
# Epoch 904/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.8025 - accuracy: 0.7282 - val_loss: 1.3367 - val_accuracy: 0.5600
# Epoch 905/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7939 - accuracy: 0.7379 - val_loss: 1.4840 - val_accuracy: 0.5390
# Epoch 906/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7852 - accuracy: 0.7374 - val_loss: 1.4147 - val_accuracy: 0.5520
# Epoch 907/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7900 - accuracy: 0.7420 - val_loss: 1.3020 - val_accuracy: 0.5765
# Epoch 908/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7720 - accuracy: 0.7455 - val_loss: 2.1757 - val_accuracy: 0.4435
# Epoch 909/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.8149 - accuracy: 0.7358 - val_loss: 1.4400 - val_accuracy: 0.5375
# Epoch 910/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.
1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7453 - accuracy: 0.7543 - val_loss: 1.3897 - val_accuracy: 0.5365
# Epoch 941/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7494 - accuracy: 0.7562 - val_loss: 1.3862 - val_accuracy: 0.5545
# Epoch 942/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7415 - accuracy: 0.7565 - val_loss: 1.3652 - val_accuracy: 0.5505
# Epoch 943/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7323 - accuracy: 0.7527 - val_loss: 1.3809 - val_accuracy: 0.5360
# Epoch 944/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7556 - accuracy: 0.7458 - val_loss: 1.3458 - val_accuracy: 0.5690
# Epoch 945/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7390 - accuracy: 0.7507 - val_loss: 1.4542 - val_accuracy: 0.5350
# Epoch 946/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7653 - accuracy: 0.7440 - val_loss: 1.5261 - val_accuracy: 0.5210
# Epoch 947/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7417 - accuracy: 0.7541 - val_loss: 1.4102 - val_accuracy: 0.5415
# Epoch 948/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7590 - accuracy: 0.7436 - val_loss: 1.4257 - val_accuracy: 0.5390
# Epoch 949/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7670 - accuracy: 0.7412 - val_loss: 1.3802 - val_accuracy: 0.5645
# Epoch 950/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7308 - accuracy: 0.7589 - val_loss: 1.5959 - val_accuracy: 0.5165
# Epoch 951/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7825 - accuracy: 0.7409 - val_loss: 1.4811 - val_accuracy: 0.5200
# Epoch 952/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7655 - accuracy: 0.7355 - val_loss: 2.2519 - val_accuracy: 0.3975
# Epoch 953/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7764 - accuracy: 0.7441 - val_loss: 1.4539 - val_accuracy: 0.5275
# Epoch 954/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7484 - accuracy: 0.7503 - val_loss: 1.3864 - val_accuracy: 0.5520
# Epoch 955/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7401 - accuracy: 0.7537 - val_loss: 1.4324 - val_accuracy: 0.5565
# Epoch 956/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7268 - accuracy: 0.7585 - val_loss: 1.3472 - val_accuracy: 0.5585
# Epoch 957/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7277 - accuracy: 0.7558 - val_loss: 1.4786 - val_accuracy: 0.5270
# Epoch 958/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7460 - accuracy: 0.7480 - val_loss: 1.4444 - val_accuracy: 0.5315
# Epoch 959/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7441 - accuracy: 0.7488 - val_loss: 1.4048 - val_accuracy: 0.5480
# Epoch 960/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7308 - accuracy: 0.7568 - val_loss: 1.3483 - val_accuracy: 0.5585
# Epoch 961/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7280 - accuracy: 0.7555 - val_loss: 1.3806 - val_accuracy: 0.5495
# Epoch 962/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7321 - accuracy: 0.7572 - val_loss: 1.6045 - val_accuracy: 0.5055
# Epoch 963/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7448 - accuracy: 0.7513 - val_loss: 1.3014 - val_accuracy: 0.5790
# Epoch 964/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7393 - accuracy: 0.7604 - val_loss: 1.7106 - val_accuracy: 0.4510
# Epoch 965/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7493 - accuracy: 0.7444 - val_loss: 1.3647 - val_accuracy: 0.5500
# Epoch 966/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7420 - accuracy: 0.7508 - val_loss: 1.4907 - val_accuracy: 0.5310
# Epoch 967/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7455 - accuracy: 0.7483 - val_loss: 1.4594 - val_accuracy: 0.5210
# Epoch 968/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7259 - accuracy: 0.7592 - val_loss: 1.4905 - val_accuracy: 0.5250
# Epoch 969/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7244 - accuracy: 0.7578 - val_loss: 1.3607 - val_accuracy: 0.5615
# Epoch 970/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7233 - accuracy: 0.7563 - val_loss: 1.5337 - val_accuracy: 0.5200
# Epoch 971/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7443 - accuracy: 0.7504 - val_loss: 1.3497 - val_accuracy: 0.5675
# Epoch 972/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7311 - accuracy: 0.7675 - val_loss: 1.4349 - val_accuracy: 0.5320
# Epoch 973/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7206 - accuracy: 0.7577 - val_loss: 1.3659 - val_accuracy: 0.5570
# Epoch 974/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7229 - accuracy: 0.7621 - val_loss: 1.4605 - val_accuracy: 0.5430
# Epoch 975/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7375 - accuracy: 0.7563 - val_loss: 1.5181 - val_accuracy: 0.5180
# Epoch 976/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7128 - accuracy: 0.7668 - val_loss: 1.3555 - val_accuracy: 0.5615
# Epoch 977/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7273 - accuracy: 0.7558 - val_loss: 1.3977 - val_accuracy: 0.5430
# Epoch 978/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7428 - accuracy: 0.7515 - val_loss: 1.4379 - val_accuracy: 0.5355
# Epoch 979/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7287 - accuracy: 0.7620 - val_loss: 1.4073 - val_accuracy: 0.5520
# Epoch 980/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7344 - accuracy: 0.7591 - val_loss: 1.4099 - val_accuracy: 0.5260
# Epoch 981/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7424 - accuracy: 0.7563 - val_loss: 1.3818 - val_accuracy: 0.5670
# Epoch 982/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7186 - accuracy: 0.7638 - val_loss: 1.4214 - val_accuracy: 0.5500
# Epoch 983/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7177 - accuracy: 0.7643 - val_loss: 1.5589 - val_accuracy: 0.5115
# Epoch 984/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7110 - accuracy: 0.7612 - val_loss: 1.4280 - val_accuracy: 0.5470
# Epoch 985/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7110 - accuracy: 0.7626 - val_loss: 1.6340 - val_accuracy: 0.4780
# Epoch 986/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7490 - accuracy: 0.7505 - val_loss: 1.5970 - val_accuracy: 0.5070
# Epoch 987/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7421 - accuracy: 0.7532 - val_loss: 1.3750 - val_accuracy: 0.5500
# Epoch 988/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7382 - accuracy: 0.7506 - val_loss: 1.4365 - val_accuracy: 0.5280
# Epoch 989/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7310 - accuracy: 0.7550 - val_loss: 1.3867 - val_accuracy: 0.5510
# Epoch 990/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7096 - accuracy: 0.7695 - val_loss: 1.5701 - val_accuracy: 0.5140
# Epoch 991/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7300 - accuracy: 0.7539 - val_loss: 1.4345 - val_accuracy: 0.5335
# Epoch 992/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7245 - accuracy: 0.7580 - val_loss: 1.3954 - val_accuracy: 0.5605
# Epoch 993/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7088 - accuracy: 0.7701 - val_loss: 1.4308 - val_accuracy: 0.5340
# Epoch 994/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7214 - accuracy: 0.7622 - val_loss: 1.3776 - val_accuracy: 0.5490
# Epoch 995/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7184 - accuracy: 0.7617 - val_loss: 1.4464 - val_accuracy: 0.5445
# Epoch 996/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7089 - accuracy: 0.7629 - val_loss: 1.4160 - val_accuracy: 0.5575
# Epoch 997/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7201 - accuracy: 0.7641 - val_loss: 1.3795 - val_accuracy: 0.5585
# Epoch 998/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7183 - accuracy: 0.7607 - val_loss: 1.4980 - val_accuracy: 0.5200
# Epoch 999/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7025 - accuracy: 0.7680 - val_loss: 1.6861 - val_accuracy: 0.4895
# Epoch 1000/1000
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7114 - accuracy: 0.7629 - val_loss: 1.5194 - val_accuracy: 0.5325
# C:\Users\Yuhan\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\engine\training.py:2342: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# C:\Users\Yuhan\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\engine\base_layer.py:1395: UserWarning: `layer.updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`layer.updates` will be removed in a future version. '
# INFO:tensorflow:Assets written to: ./models/50_60_SGD_no_dropout\assets

# %%
print(x_test[0].shape)
print()
# Out:
# (32, 32, 3)

# %%
# Display and save test images
if not os.path.exists('./figures'):
        os.mkdir('./figures')
image = x_test[0]
image2 = x_test[1]
for i in range(2):
    plt.title('test image '+str(i))
    plt.imshow(x_test[i])
    plt.savefig(
                f'./figures/test_image_{i+1}.png'
            )

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 24, 24, 50)        12200
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 50)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 60)          75060
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 60)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 960)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 300)               288300
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                3010
# =================================================================
# Total params: 378,570
# Trainable params: 378,570
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Get the conv2D and max pooling layers
layer_outputs = [layer.output for layer in model.layers]
print(layer_outputs)
activation_model = models.Model(inputs = model.input, outputs = layer_outputs)
activation_model.summary()
# Out:
# [<KerasTensor: shape=(None, 24, 24, 50) dtype=float32 (created by layer 'conv2d_2')>, <KerasTensor: shape=(None, 12, 12, 50) dtype=float32 (created by layer 'max_pooling2d_2')>, <KerasTensor: shape=(None, 8, 8, 60) dtype=float32 (created by layer 'conv2d_3')>, <KerasTensor: shape=(None, 4, 4, 60) dtype=float32 (created by layer 'max_pooling2d_3')>, <KerasTensor: shape=(None, 960) dtype=float32 (created by layer 'flatten_1')>, <KerasTensor: shape=(None, 300) dtype=float32 (created by layer 'dense_2')>, <KerasTensor: shape=(None, 10) dtype=float32 (created by layer 'dense_3')>]
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 24, 24, 50)        12200
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 50)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 60)          75060
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 60)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 960)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 300)               288300
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                3010
# =================================================================
# Total params: 378,570
# Trainable params: 378,570
# Non-trainable params: 0
# _________________________________________________________________

# %%
for i in range(2):
    image_data = np.expand_dims(x_test[i], axis=0) 
    activations = activation_model.predict(image_data)

    layer_names = []

    for layer in model.layers[:4]:
        layer_names.append(layer.name) # Names of the layers, so you can have them as part of your plot

    images_per_row = 10
    for layer_name, layer_activation in zip(layer_names, activations): # Displays the feature maps
        n_features = layer_activation.shape[-1] # Number of features in the feature map
        size = layer_activation.shape[1] #The feature map has shape (1, size, size, n_features).
        n_cols = n_features // images_per_row # Tiles the activation channels in this matrix
        display_grid = np.zeros((size * n_cols, images_per_row * size))
        for col in range(n_cols): # Tiles each filter into a big horizontal grid
            for row in range(images_per_row):
                channel_image = layer_activation[0,:, :,col * images_per_row + row]
                
                channel_image -= channel_image.mean() # Post-processes the feature to make it visually palatable
                channel_image /= channel_image.std()
                channel_image *= 64
                channel_image += 128
                channel_image = np.clip(channel_image, 0, 255).astype('uint8')
                display_grid[col * size : (col + 1) * size, # Displays the grid
                             row * size : (row + 1) * size] = channel_image
        scale = 1. / size
        plt.figure(figsize=(scale * display_grid.shape[1],
                            scale * display_grid.shape[0]))
        plt.title('Image '+str(i+1)+': '+str(layer_name))
        plt.grid(False)
        plt.imshow(display_grid, aspect='auto', cmap='gray')
        plt.savefig(
            f'./figures/feature_maps_{layer_name}_{i+1}.png'
        )
# Out:
# <ipython-input-94-c7ffaee6c5dd>:21: RuntimeWarning: invalid value encountered in true_divide
#   channel_image /= channel_image.std()

# %%
history = load_history('50_60_SGD_nodropout')
